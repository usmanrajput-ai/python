# %%
obtained_marks=45.6
total_marks=75
obtained_percentage=(obtained_marks/total_marks)*100
print(obtained_percentage)
# Out:
# 60.8

# %%
name="usman"
print(name)
# Out:
# usman

# %%
print("Hello Word")
# Out:
# Hello Word
