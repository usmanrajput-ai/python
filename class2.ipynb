# %%
print("Hello world")
print("Hello Agentic AI 2 month Course")
# Out:
# Hello world
# Hello Agentic AI 2 month Course

# %%
#String data type
name="Muhammad Usman"
print(name)
# Out:
# Muhammad Usman

# %%
# bolean data type
its_raining=True
number_of_cat=5
marks=10.5
print(its_raining)
print(marks)
print(number_of_cat)
# Out:
# True
# 10.5
# 5

# %%
#Types checking of variable
name='usman'
age=24
print(type(name))
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
#case sensitive example
age=5
Age=6
AGE=7
#Above both variable are different
print(age)
print(Age)
print(AGE)
# Out:
# 5
# 6
# 7

# %%
obtained_marks=50.5
total_marks=100

obtained_percentage=(obtained_marks/total_marks)*100
print(obtained_percentage)
# Out:
# 50.5
