# %%
#5Question.Create a variable speed. If speed is greater than 100, print "Overspeeding" otherwise print "Drive Safely".
speed = 120

if speed > 100:
    print("Overspeeding")
else:
    print("Drive Safely")
# Out:
# Overspeeding

# %%
#Quesion4.Create a variable password. If password is equal to "python123", print "Login Successful" otherwise print "Wrong Password"
password = "python123"

if password == "python123":
    print("Login Successful")
else:
    print("Wrong Password")
# Out:
# Login Successful

# %%
# 3Question.Create a variable battery. If battery is less than 20, print "Charge your phone" otherwise print "Battery is good". 
battery = 15

if battery < 20:
    print("Charge your phone")
else:
    print("Battery is good")
# Out:
# Charge your phone

# %%
#Question2.Create two variables englishMarks and mathMarks. Print which subject has higher marks. 
englishMarks = 85
mathMarks = 92

if englishMarks > mathMarks:
    print("English has higher marks")
else:
    print("Math has higher marks")
# Out:
# Math has higher marks

# %%
#Question1. Create a variable city and store your favorite city name in it. Print: "I want to visit 
city = "Makkah"
print("I want to visit", city)
# Out:
# I want to visit Makkah
